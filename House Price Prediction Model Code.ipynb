# %%
import pandas as pd

# %%
df = pd.read_csv("house_price_dataset.csv")

# %%
df.head()
# Out:
#        society_name  square_footage  bedrooms  bathrooms  age_of_house  \
# 0    Sunset Heights     2123.620357         4          3            26
# 1    Mountain Ridge     3852.142919         3          2             7
# 2       Maple Grove     3195.981825         5          4            82
# 3  Pinewood Estates     2795.975453         1          3            64
# 4        River View     1468.055921         5          2            56
#
#       lot_size  garage_size  has_pool  school_district_rating  \
# 0  8787.403033            0         1                       9
# 1  5381.033576            3         1                       1
# 2  4423.447245            1         0                       4
# 3  4602.361072            3         1                       2
# 4  7700.970665            1         1                       4
#
#    distance_to_city_center  nearby_amenities          price
# 0                12.758679                 8  482287.495008
# ...

# %%
df.columns
# Out:
# Index(['society_name', 'square_footage', 'bedrooms', 'bathrooms',
#        'age_of_house', 'lot_size', 'garage_size', 'has_pool',
#        'school_district_rating', 'distance_to_city_center', 'nearby_amenities',
#        'price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# society_name                object
# square_footage             float64
# bedrooms                     int64
# bathrooms                    int64
# age_of_house                 int64
# lot_size                   float64
# garage_size                  int64
# has_pool                     int64
# school_district_rating       int64
# distance_to_city_center    float64
# nearby_amenities             int64
# price                      float64
# dtype: object

# %%
x = df[["square_footage","bedrooms","bathrooms","age_of_house","lot_size","garage_size","has_pool","school_district_rating","distance_to_city_center","nearby_amenities"]]

# %%
y = df.price

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size = 0.1)

# %%
x_train.shape, x_test.shape
# Out:
# ((900, 10), (100, 10))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.8319605187275415

# %%
y_predicted = model.predict(x_test)

# %%
y_predicted
# Out:
# array([158008.71868118, 310344.02846918, 477712.01767774, 420837.28165111,
#        579894.52018198, 353182.1911912 , 529095.0373924 , 637109.66631485,
#        314198.27087906, 514753.34759206, 386045.49019614, 397689.08659739,
#        578543.60162575, 356114.53695541, 189924.15735153, 224097.82910715,
#        555875.50381247, 449937.38254929, 351355.87931475, 381698.68443059,
#        569960.9004925 , 429468.91643182, 441887.63695446, 414138.77296649,
#        399839.21486797, 439689.43893045, 637502.54660952, 310508.86001405,
#        415197.82209592, 353780.27902883, 437448.93045579, 284152.62258016,
#        369065.99854817, 458574.11584373, 288072.36831006, 546991.51448553,
#        563279.62475705, 442852.20328   , 399637.74346335, 519999.29164438,
#        588981.47905564, 467791.0404998 , 614032.72560424, 453785.31049041,
#        560766.98469128, 452847.7971901 , 401495.69469902, 279974.58448912,
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mae = mean_absolute_error(y_test, y_predicted)
mse = mean_squared_error(y_test, y_predicted)

# %%
print(f"Mean Absolute Error is: {mae}")
print(f"Mean Squared Error is: {mse}")
# Out:
# Mean Absolute Error is: 38677.76080547994
# Mean Squared Error is: 2470307482.591854

# %%
import joblib

# %%
joblib.dump(model,"linear_regression_house_price_prediction.pkl")
# Out:
# ['linear_regression_house_price_prediction.pkl']
